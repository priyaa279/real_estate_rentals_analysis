# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import numpy as np

# %% [markdown]
# # **Read Files**

# %%
zhvi = pd.read_csv("raw_data/ZillowHomeValueIndex.csv")
zori = pd.read_csv("raw_data/ZillowObservedRentIndex.csv")
zori1 = pd.read_csv("raw_data/ZillowObservedRentIndex1.csv")
crime_2024 = pd.read_excel("raw_data/NIBRSPublicView2024.xlsx")
crime_2025 = pd.read_excel("raw_data/NIBRSPublicView2025.xlsx")
property_listings = pd.read_csv("raw_data/PropertyListings.csv")

# %% [markdown]
# # **1. Preprocess Data**

# %% [markdown]
# ## **1.1 Property Listings Data**

# %%
property_listings.head(2)
# Out:
#      zip     price                               address    beds      baths  \
# 0  77002  $509,000      120 Pierce St, Houston, TX 77002  3 beds  3.5 baths
# 1  77002  $175,000  2016 Main St #704, Houston, TX 77002  2 beds    2 baths
#
#     sqft
# 0  2,015
# 1  1,169

# %%
property_listings
# Out:
#          zip       price                                       address  \
# 0      77002    $509,000              120 Pierce St, Houston, TX 77002
# 1      77002    $175,000          2016 Main St #704, Houston, TX 77002
# 2      77002    $160,000  2016 Main St Unit 105-107, Houston, TX 77002
# 3      77002    $250,000         2016 Main St #1502, Houston, TX 77002
# 4      77002    $250,000         2016 Main St #1809, Houston, TX 77002
# ...      ...         ...                                           ...
# 12462  77099    $340,000            12318 Bexley Dr, Houston, TX 77099
# 12463  77099    $330,000            12314 Bexley Dr, Houston, TX 77099
# 12464  77099  $1,400,000               9310 Cook Rd, Houston, TX 77099
# 12465  77099    $700,000             0 Kinghurst Dr, Houston, TX 77099
# 12466  77099  $2,600,000         10525 Bissonnet St, Houston, TX 77099
#
#          beds      baths   sqft
# 0      3 beds  3.5 baths  2,015
# 1      2 beds    2 baths  1,169
# 2      0 beds    — baths    710
# 3      2 beds    2 baths  1,145
# 4      2 beds    2 baths    908
# ...       ...        ...    ...
# 12462  4 beds    2 baths  1,896
# 12463  3 beds    2 baths  1,642
# 12464  — beds    — baths      —
# 12465  — beds    — baths      —
# 12466  — beds    — baths      —
#
# [12467 rows x 6 columns]

# %% [markdown]
# ### **Remove missing rows**

# %%
property_listings = property_listings.dropna()
property_listings
# Out:
#          zip       price                                       address  \
# 0      77002    $509,000              120 Pierce St, Houston, TX 77002
# 1      77002    $175,000          2016 Main St #704, Houston, TX 77002
# 2      77002    $160,000  2016 Main St Unit 105-107, Houston, TX 77002
# 3      77002    $250,000         2016 Main St #1502, Houston, TX 77002
# 4      77002    $250,000         2016 Main St #1809, Houston, TX 77002
# ...      ...         ...                                           ...
# 12462  77099    $340,000            12318 Bexley Dr, Houston, TX 77099
# 12463  77099    $330,000            12314 Bexley Dr, Houston, TX 77099
# 12464  77099  $1,400,000               9310 Cook Rd, Houston, TX 77099
# 12465  77099    $700,000             0 Kinghurst Dr, Houston, TX 77099
# 12466  77099  $2,600,000         10525 Bissonnet St, Houston, TX 77099
#
#          beds      baths   sqft
# 0      3 beds  3.5 baths  2,015
# 1      2 beds    2 baths  1,169
# 2      0 beds    — baths    710
# 3      2 beds    2 baths  1,145
# 4      2 beds    2 baths    908
# ...       ...        ...    ...
# 12462  4 beds    2 baths  1,896
# 12463  3 beds    2 baths  1,642
# 12464  — beds    — baths      —
# 12465  — beds    — baths      —
# 12466  — beds    — baths      —
#
# [12467 rows x 6 columns]

# %% [markdown]
# ### **Convert Price field into numeric**

# %%
property_listings.dtypes
# Out:
# zip         int64
# price      object
# address    object
# beds       object
# baths      object
# sqft       object
# dtype: object

# %%
property_listings['price'] = (
    property_listings['price']
    .replace('[\$,]','', regex=True)
    .str.strip()
    .replace('', pd.NA)
)

property_listings['price'] = pd.to_numeric(property_listings['price'], errors='coerce')

property_listings.dropna(subset=['price'], inplace=True)

# %% [markdown]
# ### **Convert zipcode to string**

# %%
property_listings['zip'] = property_listings['zip'].astype('str')
property_listings.rename(columns={'zip':'zipcode'}, inplace=True)

# %% [markdown]
# ### **Convert Beds field into numeric**

# %%
property_listings['beds']=property_listings['beds'].str.extract(r'(\d+)')
property_listings.dropna(subset=['beds'],inplace=True)
# property_listings['beds'] = property_listings['beds'].astype(int)

# %% [markdown]
# ### **Convert Baths field to numeric**

# %%
property_listings['baths']=property_listings['baths'].str.extract(r'(\d+\.?\d*)')
property_listings.dropna(subset=['baths'],inplace=True)

# %% [markdown]
# ### **Convert Square Footage to Numeric**

# %%
property_listings = property_listings[property_listings['sqft'].str.replace(',', '').str.isnumeric()]
property_listings['sqft'] = property_listings['sqft'].replace(',','',regex=True).astype(float)
# Out:
# <ipython-input-12-6658f79375d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_listings['sqft'] = property_listings['sqft'].replace(',','',regex=True).astype(float)

# %% [markdown]
# ### **Address into multiple fields**

# %%
property_listings['city']=property_listings['address'].apply(lambda x: x.split(',')[-2].strip())
property_listings['state']=property_listings['address'].apply(lambda x: x.split(',')[-1].split()[0].strip())
# Out:
# <ipython-input-13-feeea06289dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_listings['city']=property_listings['address'].apply(lambda x: x.split(',')[-2].strip())
# <ipython-input-13-feeea06289dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_listings['state']=property_listings['address'].apply(lambda x: x.split(',')[-1].split()[0].strip())

# %% [markdown]
# ### **Select only city= 'Houston' rows**

# %%
property_listings = property_listings[property_listings['city'] == 'Houston']

# %%
property_listings = property_listings.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
property_listings
# Out:
#       zipcode     price                                     address beds  \
# 0       77002  509000.0            120 pierce st, houston, tx 77002    3
# 1       77002  175000.0        2016 main st #704, houston, tx 77002    2
# 3       77002  250000.0       2016 main st #1502, houston, tx 77002    2
# 4       77002  250000.0       2016 main st #1809, houston, tx 77002    2
# 5       77002  225000.0  300 st joseph pkwy #203, houston, tx 77002    1
# ...       ...       ...                                         ...  ...
# 12459   77099  108000.0  9797 leawood blvd #1411, houston, tx 77099    2
# 12460   77099  320000.0   12510 shannon hills dr, houston, tx 77099    3
# 12461   77099  330000.0          12326 bexley dr, houston, tx 77099    3
# 12462   77099  340000.0          12318 bexley dr, houston, tx 77099    4
# 12463   77099  330000.0          12314 bexley dr, houston, tx 77099    3
#
#       baths    sqft     city state
# 0       3.5  2015.0  houston    tx
# 1         2  1169.0  houston    tx
# 3         2  1145.0  houston    tx
# 4         2   908.0  houston    tx
# 5         1  1015.0  houston    tx
# ...     ...     ...      ...   ...
# 12459     2  1068.0  houston    tx
# 12460     2  1642.0  houston    tx
# 12461     2  1642.0  houston    tx
# 12462     2  1896.0  houston    tx
# 12463     2  1642.0  houston    tx
#
# [10596 rows x 8 columns]

# %% [markdown]
# ## **1.2 Zillow Home Value Index Data**

# %%
zhvi.dtypes
# Out:
# RegionID        int64
# SizeRank        int64
# RegionName      int64
# RegionType     object
# StateName      object
#                ...
# 2024-10-31    float64
# 2024-11-30    float64
# 2024-12-31    float64
# 2025-01-31    float64
# 2025-02-28    float64
# Length: 311, dtype: object

# %%
zhvi.head(2)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  209414.041482
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  131918.577791
#
#    ...     2024-05-31     2024-06-30     2024-07-31     2024-08-31  \
# 0  ...  495936.411427  496241.930564  495863.854951  496270.138911
# 1  ...  584298.024483  589505.709784  594184.490210  599212.219688
#
#       2024-09-30     2024-10-31     2024-11-30     2024-12-31     2025-01-31  \
# 0  496959.078506  498079.880762  498797.284325  499214.713899  499637.493567
# 1  605133.048238  610430.184997  613806.807609  615811.473737  616448.543879
#
#       2025-02-28
# 0  499316.860950
# 1  618664.793443
#
# [2 rows x 311 columns]

# %% [markdown]
# ### **Replace NA values with 0**

# %%
zhvi.fillna(0,inplace=True)

# %% [markdown]
# ### **Verify Consistency Between 'StateName' and 'State'**

# %%
(zhvi['StateName'] == zhvi['State']).all()
# Out:
# np.True_

# %% [markdown]
# ### **Remove repeated or unecessary columns**

# %%
zhvi = zhvi.drop(columns=['RegionType','StateName'])

# %% [markdown]
# ### **Rename columns**

# %%
zhvi.rename(columns={'RegionID':'region_id','SizeRank':'size_rank','RegionName':'zipcode','CountyName':'county'},inplace=True)

# %% [markdown]
# ### **Reshape ZHVI Data to Long Format and Parse Dates**

# %%
id_vars = ['region_id','size_rank','zipcode','county','State','City','Metro']

zhvi = zhvi.melt(id_vars = id_vars, var_name = "date", value_name = "zhvi_value")

zhvi['date'] = pd.to_datetime(zhvi['date'])

# %% [markdown]
# ### **Convert zipcode to str**

# %%
zhvi['zipcode'] = zhvi['zipcode'].astype('str')

# %%
zhvi.dtypes
# Out:
# region_id              int64
# size_rank              int64
# zipcode               object
# county                object
# State                 object
# City                  object
# Metro                 object
# date          datetime64[ns]
# zhvi_value           float64
# dtype: object

# %% [markdown]
# ### **Standardize Column Names and Lowercase String Columns**

# %%
zhvi = zhvi.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
zhvi.columns = zhvi.columns.str.lower()
zhvi.head(2)
# Out:
#    region_id  size_rank zipcode            county state      city  \
# 0      91982          1   77494  fort bend county    tx      katy
# 1      61148          2    8701      ocean county    nj  lakewood
#
#                                    metro       date     zhvi_value
# 0   houston-the woodlands-sugar land, tx 2000-01-31  209414.041482
# 1  new york-newark-jersey city, ny-nj-pa 2000-01-31  131918.577791

# %% [markdown]
# ## **1.3 Zillow Observed Rent Index Data**

# %%
zori.head(1)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State  City  \
# 0     91982         1       77494        zip        TX    TX  Katy
#
#                                   Metro        CountyName   2015-01-31  ...  \
# 0  Houston-The Woodlands-Sugar Land, TX  Fort Bend County  1523.412518  ...
#
#     2024-05-31   2024-06-30  2024-07-31   2024-08-31   2024-09-30  \
# 0  1929.997123  1932.100456  1928.31139  1933.758912  1932.781268
#
#     2024-10-31   2024-11-30   2024-12-31  2025-01-31   2025-02-28
# 0  1932.649706  1942.156741  1948.045995  1951.49988  1944.607081
#
# [1 rows x 131 columns]

# %% [markdown]
# ### **Replace NA values with 0**

# %%
zori.fillna(0, inplace=True)
zori1.fillna(0, inplace=True)

# %% [markdown]
# ### **Verify Consistency Between 'StateName' and 'State'**

# %%
(zori['StateName'] == zori['State']).all()
(zori1['StateName'] == zori1['State']).all()
# Out:
# np.True_

# %% [markdown]
# ### **Remove repeated or unecessary columns**

# %%
zori = zori.drop(columns=['RegionType','StateName'])
zori1 = zori1.drop(columns=['RegionType','StateName'])

# %% [markdown]
# ### **Rename columns**

# %%
zori.rename(columns={'RegionID':'region_id','SizeRank':'size_rank','RegionName':'zipcode','CountyName':'county'},inplace=True)
zori1.rename(columns={'RegionID':'region_id','SizeRank':'size_rank','RegionName':'zipcode','CountyName':'county'},inplace=True)

# %% [markdown]
# ### **Reshape ZHVI Data to Long Format and Parse Dates**

# %%
id_vars = ['region_id','size_rank','zipcode','county','State','City','Metro']

zori = zori.melt(id_vars = id_vars, var_name = "date", value_name = "zori_value")

zori['date'] = pd.to_datetime(zori['date'])

zori1 = zori1.melt(id_vars = id_vars, var_name = "date", value_name = "zori_value")

zori1['date'] = pd.to_datetime(zori1['date'])

# %% [markdown]
# ### **Convert zipcode to str**

# %%
zori['zipcode'] = zori['zipcode'].astype('str')
zori1['zipcode'] = zori1['zipcode'].astype('str')

# %%
zori.dtypes
# Out:
# region_id              int64
# size_rank              int64
# zipcode               object
# county                object
# State                 object
# City                  object
# Metro                 object
# date          datetime64[ns]
# zori_value           float64
# dtype: object

# %% [markdown]
# ### **Standardize Column Names and Lowercase String Columns**

# %%
zori = zori.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
zori.columns = zori.columns.str.lower()

zori1 = zori1.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
zori1.columns = zori1.columns.str.lower()

# %% [markdown]
# ## **1.3 Crime Data 2024**

# %%
crime_2024.head()
# Out:
#    Incident RMSOccurrenceDate  RMSOccurrenceHour NIBRSClass  \
# 0     12124        2024-01-01                  0        90C
# 1     14424        2024-01-01                  0        90C
# 2     15924        2024-01-01                  0        13A
# 3     17024        2024-01-01                  0        520
# 4     17624        2024-01-01                  0        13A
#
#         NIBRSDescription  OffenseCount   Beat  \
# 0     Disorderly conduct             1   8C30
# 1     Disorderly conduct             1   8C10
# 2     Aggravated Assault             1   6B10
# 3  Weapon law violations             1  16E20
# 4     Aggravated Assault             1   1A20
#
#                                 Premise StreetNo StreetName StreetType Suffix  \
# 0  Residence, Home (Includes Apartment)     8404   EASTOVER         ST    NaN
# 1  Residence, Home (Includes Apartment)     7125      GLASS         ST    NaN
# 2  Residence, Home (Includes Apartment)      329   INNSDALE         DR    NaN
# 3  Residence, Home (Includes Apartment)     3727  DALMATIAN         DR    NaN
# 4                   Parking Lot, Garage      230    ALABAMA         ST      W
#
#       City  ZIPCode  MapLongitude  MapLatitude
# 0  HOUSTON  77028.0    -95.271852    29.823953
# 1  HOUSTON  77016.0    -95.325797    29.824464
# 2  HOUSTON  77076.0    -95.371408    29.850945
# 3  HOUSTON  77045.0    -95.432224    29.618177
# 4  HOUSTON  77006.0    -95.382675    29.738908

# %%
crime_2024.dtypes
# Out:
# Incident                      int64
# RMSOccurrenceDate    datetime64[ns]
# RMSOccurrenceHour             int64
# NIBRSClass                   object
# NIBRSDescription             object
# OffenseCount                  int64
# Beat                         object
# Premise                      object
# StreetNo                     object
# StreetName                   object
# StreetType                   object
# Suffix                       object
# City                         object
# ZIPCode                     float64
# MapLongitude                float64
# MapLatitude                 float64
# dtype: object

# %% [markdown]
# ### **Remove unecessary columns**

# %%
cols_to_drop = ['Incident', 'RMSOccurrenceHour', 'NIBRSClass', 'Beat', 'Suffix']
crime_2024 = crime_2024.drop(columns=cols_to_drop)

# %% [markdown]
# ### **Rename columns**

# %%
crime_2024.rename(columns={'RMSOccurrenceDate':'occurrence_date','NIBRSDescription':'nibrs_description','OffenseCount':'offense_count','Premise':'premise','StreetNo':'street_no','StreetName':'street_name','StreetType':'street_type','City':'city','ZIPCode':'zipcode','MapLongitude':'longitude','MapLatitude':'latitude'},inplace=True)

# %% [markdown]
# ### **Drop NA ZIP Codes and Convert to String**

# %%
crime_2024 = crime_2024.dropna(subset=['zipcode'])
crime_2024['zipcode']=crime_2024['zipcode'].astype(int).astype(str)

# %% [markdown]
# ### **Convert All String Columns to Lowercase**

# %%
crime_2024 = crime_2024.apply(lambda col: col.str.lower() if col.dtype == "object" else col)

# %%
crime_2024
# Out:
#        occurrence_date          nibrs_description  offense_count  \
# 0           2024-01-01         disorderly conduct              1
# 1           2024-01-01         disorderly conduct              1
# 2           2024-01-01         aggravated assault              1
# 3           2024-01-01      weapon law violations              1
# 4           2024-01-01         aggravated assault              1
# ...                ...                        ...            ...
# 250163      2024-12-31             simple assault              1
# 250164      2024-12-31         disorderly conduct              1
# 250165      2024-12-31  drug, narcotic violations              1
# 250166      2024-12-31  drug equipment violations              1
# 250167      2024-12-31         aggravated assault              1
#
#                                      premise street_no      street_name  \
# 0       residence, home (includes apartment)      8404         eastover
# 1       residence, home (includes apartment)      7125            glass
# 2       residence, home (includes apartment)       329         innsdale
# 3       residence, home (includes apartment)      3727        dalmatian
# 4                        parking lot, garage       230          alabama
# ...                                      ...       ...              ...
# 250163  residence, home (includes apartment)      1514           bingle
# 250164  residence, home (includes apartment)       701         victoria
# 250165  residence, home (includes apartment)       701         victoria
# 250166  residence, home (includes apartment)       701         victoria
# 250167          highway, road, street, alley     13431  live oak forest
#
#        street_type     city zipcode  longitude   latitude
# 0               st  houston   77028 -95.271852  29.823953
# 1               st  houston   77016 -95.325797  29.824464
# 2               dr  houston   77076 -95.371408  29.850945
# 3               dr  houston   77045 -95.432224  29.618177
# 4               st  houston   77006 -95.382675  29.738908
# ...            ...      ...     ...        ...        ...
# 250163          rd  houston   77055 -95.500562  29.797544
# 250164          dr  houston   77022 -95.388540  29.833788
# 250165          dr  houston   77022 -95.388540  29.833788
# 250166          dr  houston   77022 -95.388540  29.833788
# 250167         NaN  houston   77049 -95.209478  29.822376
#
# [246416 rows x 11 columns]

# %%
crime_2024.dtypes
# Out:
# occurrence_date      datetime64[ns]
# nibrs_description            object
# offense_count                 int64
# premise                      object
# street_no                    object
# street_name                  object
# street_type                  object
# city                         object
# zipcode                      object
# longitude                   float64
# latitude                    float64
# dtype: object

# %% [markdown]
# ## **1.4 Crime Data 2025**

# %% [markdown]
# ### **Remove unecessary columns**

# %%
cols_to_drop = ['Incident', 'RMSOccurrenceHour', 'NIBRSClass', 'Beat', 'Suffix','month']
crime_2025 = crime_2025.drop(columns = cols_to_drop)

# %% [markdown]
# ### **Rename columns**

# %%
crime_2025.rename(columns={'RMSOccurrenceDate':'occurrence_date','NIBRSDescription':'nibrs_description','OffenseCount':'offense_count','Premise':'premise','StreetNo':'street_no','StreetName':'street_name','StreetType':'street_type','City':'city','ZIPCode':'zipcode','MapLongitude':'longitude','MapLatitude':'latitude'},inplace=True)

# %% [markdown]
# ### **Drop NA ZIP Codes and Convert to String**

# %%
crime_2025 = crime_2025.dropna(subset=['zipcode'])
crime_2025['zipcode'] = crime_2025['zipcode'].astype(int).astype(str)

# %% [markdown]
# ### **Convert All String Columns to Lowercase**

# %%
crime_2025  = crime_2025.apply(lambda col:  col.str.lower() if col.dtype == "object" else col)

# %%
crime_2025
# Out:
#       occurrence_date                          nibrs_description  \
# 0          2025-01-01                         aggravated assault
# 1          2025-01-01                  drug, narcotic violations
# 2          2025-01-01                         aggravated assault
# 3          2025-01-01                         all other offenses
# 4          2025-01-01                         disorderly conduct
# ...               ...                                        ...
# 35039      2025-02-28                         aggravated assault
# 35040      2025-02-28                         all other offenses
# 35041      2025-02-28                   theft from motor vehicle
# 35042      2025-02-28                        motor vehicle theft
# 35043      2025-02-28  theft of motor vehicle parts or accessory
#
#        offense_count                               premise street_no  \
# 0                  1  residence, home (includes apartment)       NaN
# 1                  1  residence, home (includes apartment)       NaN
# 2                  1  residence, home (includes apartment)       NaN
# 3                  1  residence, home (includes apartment)       NaN
# 4                  1                   parking lot, garage       NaN
# ...              ...                                   ...       ...
# 35039              2    arena/stadium/fairgrounds/coliseum       NaN
# 35040              1    arena/stadium/fairgrounds/coliseum       NaN
# 35041              1                   parking lot, garage       NaN
# 35042              1  residence, home (includes apartment)       NaN
# 35043              1  residence, home (includes apartment)       NaN
#
#        street_name street_type     city zipcode  longitude   latitude
# 0         sherwood          ln  houston   77092 -95.458005  29.814084
# 1         sherwood          ln  houston   77092 -95.458005  29.814084
# 2        telephone          rd  houston   77075 -95.285279  29.618563
# 3          sumpter         NaN  houston   77026 -95.338518  29.779765
# 4        crestdale          dr  houston   77080 -95.530849  29.821221
# ...            ...         ...      ...     ...        ...        ...
# 35039       fannin          st  houston   77054 -95.403217  29.683226
# 35040       fannin          st  houston   77054 -95.403217  29.683226
# 35041     congress          st  houston   77002 -95.359659  29.761623
# 35042  saddle rock          dr  houston   77037 -95.409179  29.891754
# 35043  little york          rd  houston   77037 -95.391109  29.869961
#
# [34505 rows x 11 columns]

# %%
crime_2025.dtypes
# Out:
# occurrence_date      datetime64[ns]
# nibrs_description            object
# offense_count                 int64
# premise                      object
# street_no                    object
# street_name                  object
# street_type                  object
# city                         object
# zipcode                      object
# longitude                   float64
# latitude                    float64
# dtype: object

# %% [markdown]
# ## **Save df to csv files**

# %%
property_listings.to_csv("property_listings.csv", index=False)
zhvi.to_csv("zhvi.csv", index=False)
zori.to_csv("zori.csv", index=False)
zori1.to_csv("zori1.csv", index=False)
crime_2024.to_csv("crime_2024.csv", index=False)
crime_2025.to_csv("crime_2025.csv", index=False)
